# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
# Loading data
file_path = Path("owid-covid-data.csv")
df = pd.read_csv(file_path)
df.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
# Selecting specific columns using loc() method
selection = df.loc[:164946,['date','icu_patients_per_million','new_deaths_smoothed','new_vaccinations_smoothed_per_million', 'gdp_per_capita']]
selection.head()
# Out:
#          date  icu_patients_per_million  new_deaths_smoothed  \
# 0  2020-02-24                       NaN                  NaN
# 1  2020-02-25                       NaN                  NaN
# 2  2020-02-26                       NaN                  NaN
# 3  2020-02-27                       NaN                  NaN
# 4  2020-02-28                       NaN                  NaN
#
#    new_vaccinations_smoothed_per_million  gdp_per_capita
# 0                                    NaN        1803.987
# 1                                    NaN        1803.987
# 2                                    NaN        1803.987
# 3                                    NaN        1803.987
# 4                                    NaN        1803.987

# %%
# looking at info on our selected columns
selection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164945 entries, 0 to 164944
# Data columns (total 5 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   date                                   164945 non-null  object
#  1   icu_patients_per_million               23235 non-null   float64
#  2   new_deaths_smoothed                    144142 non-null  float64
#  3   new_vaccinations_smoothed_per_million  83406 non-null   float64
#  4   gdp_per_capita                         137355 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 6.3+ MB

# %%
# checking for nulls
selection.isnull().sum()
# Out:
# date                                          0
# icu_patients_per_million                 141710
# new_deaths_smoothed                       20803
# new_vaccinations_smoothed_per_million     81539
# gdp_per_capita                            27590
# dtype: int64

# %%
# dropping nulls
clean_selection = selection.dropna()

# %%
# double checking there are no nulls after drop
clean_selection.isnull().sum()
# Out:
# date                                     0
# icu_patients_per_million                 0
# new_deaths_smoothed                      0
# new_vaccinations_smoothed_per_million    0
# gdp_per_capita                           0
# dtype: int64

# %%
# looking for duplicates
print(f'Duplicate entries: {clean_selection.duplicated().sum()}')
# Out:
# Duplicate entries: 0

# %%
# checking the dataframe as a whole
clean_selection.head()
# Out:
#             date  icu_patients_per_million  new_deaths_smoothed  \
# 2555  2021-01-30                     0.740                3.857
# 2557  2021-02-01                     0.650                4.000
# 2558  2021-02-02                     0.516                3.857
# 2561  2021-02-05                     0.471                3.571
# 2564  2021-02-08                     0.560                3.429
#
#       new_vaccinations_smoothed_per_million  gdp_per_capita
# 2555                                    1.0       13913.839
# 2557                                   56.0       13913.839
# 2558                                   63.0       13913.839
# 2561                                   72.0       13913.839
# 2564                                   84.0       13913.839

# %%
# checking info on rows and columns of new dataframe
clean_selection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14230 entries, 2555 to 156684
# Data columns (total 5 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   date                                   14230 non-null  object
#  1   icu_patients_per_million               14230 non-null  float64
#  2   new_deaths_smoothed                    14230 non-null  float64
#  3   new_vaccinations_smoothed_per_million  14230 non-null  float64
#  4   gdp_per_capita                         14230 non-null  float64
# dtypes: float64(4), object(1)
# memory usage: 667.0+ KB

# %%
# saving the dataframe as a csv
output_file_path= "clean_selected_covid_data.csv"
clean_selection.to_csv(output_file_path, index=False)

# %%
# preparing the data to meet scikit-learn library requirements
X = clean_selection.new_vaccinations_smoothed_per_million.values.reshape(-1, 1)

# %%
clean_selection.drop("date", axis=1, inplace=True)
clean_selection.head()
# Out:
# C:\Users\mali_\anaconda3\envs\PythonData2\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       icu_patients_per_million  new_deaths_smoothed  \
# 2555                     0.740                3.857
# 2557                     0.650                4.000
# 2558                     0.516                3.857
# 2561                     0.471                3.571
# 2564                     0.560                3.429
#
#       new_vaccinations_smoothed_per_million  gdp_per_capita
# 2555                                    1.0       13913.839
# 2557                                   56.0       13913.839
# 2558                                   63.0       13913.839
# 2561                                   72.0       13913.839
# 2564                                   84.0       13913.839

# %%
#clean_selection.drop("location", axis=1, inplace=True)
#clean_selection.head()

# %%
#X.head(10)X = pd.get_dummies(clean_selection, columns=["new_vaccinations_smoothed_per_million", "icu_patients_per_million"])
#X.head(10)

# %%
#clean_scaled = StandardScaler().fit_transform(X)X = pd.get_dummies(clean_selection, columns=["new_vaccinations_smoothed_per_million", "icu_patients_per_million"])

# %%
#pca = PCA(n_components=3)
#clean_pca = pca.fit_transform(clean_scaled)

# %%
# assign target variable to y
#y = clean_selection.icu_patients_per_million

# %%
# Create an elbow curve to find the best value for K.
# YOUR CODE HERE
# Find the best value for K
#inertia = []
#k = list(range(1, 11))

# Calculate the inertia for the range of K values
#for i in k:
 #   km = KMeans(n_clusters=i, random_state=0)
  #  km.fit(clean_pca)
   # inertia.append(km.inertia_)

# Create the elbow curve
#elbow_data = {"k": k, "inertia": inertia}
#df_elbow = pd.DataFrame(elbow_data)
#df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")

# %%
# Initialize the K-Means model.
# YOUR CODE HERE
#model = KMeans(n_clusters=4, random_state=0)
# Fit the model
# YOUR CODE HERE
#model.fit(clean_pca)
# Predict clusters
# YOUR CODE HERE
#predictions = model.predict(clean_pca)

# %% [markdown]
# # 3d plot
# fig = px.scatter_3d(
#     clean_selection,
#     x="new_vaccinations_smoothed_per_million",
#     y="icu_patients_per_million",
#     z="new_deaths",
#     color="new_deaths",
#     symbol="new_deaths",
#     width=800,
# )
# fig.update_layout(legend=dict(x=0, y=1))
# fig.show()

# %%
X = pd.get_dummies(clean_selection, columns=["new_vaccinations_smoothed_per_million", "gdp_per_capita"])
X.head(10)
# Out:
#       icu_patients_per_million  new_deaths_smoothed  \
# 2555                     0.740                3.857
# 2557                     0.650                4.000
# 2558                     0.516                3.857
# 2561                     0.471                3.571
# 2564                     0.560                3.429
# 2566                     0.560                3.714
# 2568                     0.493                3.286
# 2569                     0.448                3.714
# 2570                     0.426                3.571
# 2575                     0.403                3.143
#
#       new_vaccinations_smoothed_per_million_0.0  \
# 2555                                          0
# 2557                                          0
# 2558                                          0
# 2561                                          0
# 2564                                          0
# 2566                                          0
# 2568                                          0
# 2569                                          0
# 2570                                          0
# 2575                                          0
#
#       new_vaccinations_smoothed_per_million_1.0  \
# 2555                                          1
# 2557                                          0
# 2558                                          0
# 2561                                          0
# 2564                                          0
# 2566                                          0
# 2568                                          0
# 2569                                          0
# 2570                                          0
# 2575                                          0
#
#       new_vaccinations_smoothed_per_million_2.0  \
# 2555                                          0
# 2557                                          0
# 2558                                          0
# 2561                                          0
# 2564                                          0
# 2566                                          0
# 2568                                          0
# 2569                                          0
# 2570                                          0
# 2575                                          0
#
#       new_vaccinations_smoothed_per_million_3.0  \
# 2555                                          0
# 2557                                          0
# 2558                                          0
# 2561                                          0
# 2564                                          0
# 2566                                          0
# 2568                                          0
# 2569                                          0
# 2570                                          0
# 2575                                          0
#
#       new_vaccinations_smoothed_per_million_5.0  \
# 2555                                          0
# 2557                                          0
# 2558                                          0
# 2561                                          0
# 2564                                          0
# 2566                                          0
# 2568                                          0
# 2569                                          0
# 2570                                          0
# 2575                                          0
#
#       new_vaccinations_smoothed_per_million_6.0  \
# 2555                                          0
# 2557                                          0
# 2558                                          0
# 2561                                          0
# 2564                                          0
# 2566                                          0
# 2568                                          0
# 2569                                          0
# 2570                                          0
# 2575                                          0
#
#       new_vaccinations_smoothed_per_million_7.0  \
# 2555                                          0
# 2557                                          0
# 2558                                          0
# 2561                                          0
# 2564                                          0
# 2566                                          0
# 2568                                          0
# 2569                                          0
# 2570                                          0
# 2575                                          0
#
#       new_vaccinations_smoothed_per_million_8.0  ...  \
# 2555                                          0  ...
# 2557                                          0  ...
# 2558                                          0  ...
# 2561                                          0  ...
# 2564                                          0  ...
# 2566                                          0  ...
# 2568                                          0  ...
# 2569                                          0  ...
# 2570                                          0  ...
# 2575                                          0  ...
#
#       gdp_per_capita_45229.245  gdp_per_capita_45436.686  \
# 2555                         0                         0
# 2557                         0                         0
# 2558                         0                         0
# 2561                         0                         0
# 2564                         0                         0
# 2566                         0                         0
# 2568                         0                         0
# 2569                         0                         0
# 2570                         0                         0
# 2575                         0                         0
#
#       gdp_per_capita_46682.515  gdp_per_capita_46949.283  \
# 2555                         0                         0
# 2557                         0                         0
# 2558                         0                         0
# 2561                         0                         0
# 2564                         0                         0
# 2566                         0                         0
# 2568                         0                         0
# 2569                         0                         0
# 2570                         0                         0
# 2575                         0                         0
#
#       gdp_per_capita_48472.545  gdp_per_capita_54225.446  \
# 2555                         0                         0
# 2557                         0                         0
# 2558                         0                         0
# 2561                         0                         0
# 2564                         0                         0
# 2566                         0                         0
# 2568                         0                         0
# 2569                         0                         0
# 2570                         0                         0
# 2575                         0                         0
#
#       gdp_per_capita_57410.166  gdp_per_capita_67335.293  \
# 2555                         0                         0
# 2557                         0                         0
# 2558                         0                         0
# 2561                         0                         0
# 2564                         0                         0
# 2566                         0                         0
# 2568                         0                         0
# 2569                         0                         0
# 2570                         0                         0
# 2575                         0                         0
#
#       gdp_per_capita_85535.383  gdp_per_capita_94277.965
# 2555                         0                         0
# 2557                         0                         0
# 2558                         0                         0
# 2561                         0                         0
# 2564                         0                         0
# 2566                         0                         0
# 2568                         0                         0
# 2569                         0                         0
# 2570                         0                         0
# 2575                         0                         0
#
# [10 rows x 7756 columns]

# %%
X.shape
# Out:
# (14230, 7756)

# %%
# assign target variable to y
y = clean_selection.icu_patients_per_million

# %%
y.shape
# Out:
# (14230,)

# %%
y
# Out:
# 2555       0.740
# 2557       0.650
# 2558       0.516
# 2561       0.471
# 2564       0.560
#            ...
# 156680    31.413
# 156681    30.584
# 156682    28.917
# 156683    28.265
# 156684    26.797
# Name: icu_patients_per_million, Length: 14230, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1
                                                )
X_train.shape
# Out:
# (10672, 7756)
